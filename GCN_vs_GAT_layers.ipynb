# %%
from setup import *

# %%
# import cora dataset only
cora_dataset = Planetoid(root='/tmp/Cora', name='Cora')
EPOCHS = 100

# %% [markdown]
# ## GAT

# %%
# dictionary of layer # : test accurarcy on CORA dataset
gat_layer_performance = {layer_num: mod_layers_GAT(cora_dataset,
                                                                layer_num,
                                                                epochs = EPOCHS) 
                                                                for layer_num in range(2, 30)}
print(gat_layer_performance)
# Out:
# {2: 0.77, 3: 0.778, 4: 0.771, 5: 0.778, 6: 0.777, 7: 0.761, 8: 0.764, 9: 0.757, 10: 0.752, 11: 0.731, 12: 0.765, 13: 0.752, 14: 0.732, 15: 0.757, 16: 0.762, 17: 0.315, 18: 0.425, 19: 0.746, 20: 0.532, 21: 0.13, 22: 0.196, 23: 0.504, 24: 0.15, 25: 0.382, 26: 0.467, 27: 0.103, 28: 0.319, 29: 0.321}

# %% [markdown]
# Graphs to visualize test accurarcy change as layer numbers change for GAT

# %%
layers, acc = gat_layer_performance.keys(), gat_layer_performance.values()
plt.plot(layers, acc)
plt.title('GAT Layer Number-Test Accuracy Performance on CORA dataset')
plt.xlabel('Layers')
plt.ylabel('Test Acc')
plt.show()

# %% [markdown]
# ## GCN

# %%
# dictionary of layer # : test accurarcy on CORA dataset
gcn_layer_performance = {layer_num: mod_layers_GCN(cora_dataset, 
                                                                layer_num, 
                                                                epochs = EPOCHS) 
                                                                for layer_num in range(2, 30)}
print(gcn_layer_performance)
# Out:
# {2: 0.797, 3: 0.798, 4: 0.783, 5: 0.78, 6: 0.759, 7: 0.734, 8: 0.687, 9: 0.712, 10: 0.454, 11: 0.345, 12: 0.416, 13: 0.419, 14: 0.166, 15: 0.369, 16: 0.171, 17: 0.161, 18: 0.155, 19: 0.139, 20: 0.15, 21: 0.14, 22: 0.144, 23: 0.17, 24: 0.159, 25: 0.158, 26: 0.173, 27: 0.159, 28: 0.106, 29: 0.142}

# %% [markdown]
# Graphs to visualize test accurarcy change as layer numbers change for GCN

# %%
layers, acc = gcn_layer_performance.keys(), gcn_layer_performance.values()
plt.plot(layers, acc, color = 'darkorange')
plt.title('GCN Layer Number-Test Accuracy Performance on CORA dataset')
plt.xlabel('Layers')
plt.ylabel('Test Acc')
plt.show()
